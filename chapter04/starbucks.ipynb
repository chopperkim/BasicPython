# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

from selenium.webdriver import Chrome, ActionChains, Keys

driver = Chrome()
driver.maximize_window()

url = 'https://www.starbucks.co.kr/store/store_map.do?disp=locale'
driver.get(url)

time.sleep(1.214234)
driver.find_element(By.XPATH, '//*[@id="container"]/div/form/fieldset/div/section/article[1]/article/article[2]/div[1]/div[2]/ul/li[5]/a').click()
time.sleep(2.123125423)
driver.find_element(By.XPATH, '//*[@id="mCSB_2_container"]/ul/li[1]/a').click()
time.sleep(1.52311)

li_list = driver.find_elements(By.CSS_SELECTOR, '#mCSB_3_container > ul > li')
wrapper = driver.find_element(By.CSS_SELECTOR, '#mCSB_3_container')
daejeon_starbucks = []
for li, idx in zip(li_list, range(len(li_list))):
    print(idx)
    # 위도와 경도로 주소를 알 수 있음 reverse geolocation
    print(li.get_attribute('data-name'))
    print(li.find_element(By.CSS_SELECTOR, '.result_details').text)
    if idx % 2 == 0:
        time.sleep(1)
        driver.execute_script('arguments[0].scrollIntoView()', li)
        # daejeon_starbucks.append({'index':li.get_attribute('data-index'), 'name': li.get_attribute('data-name'), 'lat': li.get_attribute('data-lat'), 'lng': li.get_attribute('data-long'), 'code': li.get_attribute('data-code'), 'score_cd': li.get_attribute('data-storecd')})

# print(daejeon_starbucks)
# Out:
# 0
# 대전한남대DT
# 대전광역시 대덕구 한밭대로 1122 (중리동)
# 1522-3232
# 1
# 대전IC DT
# 대전광역시 대덕구 동서대로 1776 (비래동)
# 1522-3232
# 2
# 대전신탄진DT
# 대전광역시 대덕구 대덕대로 1544 (석봉동)
# 1522-3232
# 3
# 대전송촌
# 대전광역시 대덕구 송촌북로36번길 36, 1층 (송촌동)
# 1522-3232
# 4
# 신탄진금강DT
# 대전광역시 대덕구 신탄진로 866 (신탄진동)
# 1522-3232
# 5
# 대전터미널DT
# 대전광역시 동구 동서대로 1658 (성남동)
# 1522-3232
# 6
# 대전판암DT
# 대전광역시 동구 옥천로 118 (판암동)
# 1522-3232
# 7
# 대전스타일마켓
# 대전광역시 동구 동서대로 1689, 2층 (용전동)
# 1522-3232
# 8
# 대전가오
# 대전광역시 동구 동구청로 101 (가오동)
# 1522-3232
# 9
# 대전신흥역DT
# 대전광역시 동구 옥천로 89 (판암동)
# 1522-3232
# 10
# 대전용운
# 대전광역시 동구 동부로 178 (용운동)
# 1522-3232
# 11
# 대전용전DT
# 대전광역시 동구 한밭대로 1239 (용전동)
# 1522-3232
# 12
# 대전정부청사역
# 대전광역시 서구 한밭대로 755 (둔산동)
# 1522-3232
# 13
# 대전건양대병원
# 대전광역시 서구 관저동로 170 (관저동)1층
# 1522-3232
# 14
# 대전탄방역
# 대전광역시 서구 문정로2번길 95 (탄방동)
# 1522-3232
# 15
# 대전복수
# 대전광역시 서구 복수남로 28 (복수동)
# 1522-3232
# 16
# 대전둔산남로
# 대전광역시 서구 둔산남로 100 (탄방동)
# 1522-3232
# 17
# 대전둔산로
# 대전광역시 서구 대덕대로241번길 35 (둔산동)
# 1522-3232
# 18
# 대전법원
# 대전광역시 서구 둔산로123번길 43 (둔산동)
# ...
